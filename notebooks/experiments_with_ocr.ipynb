# %%
# !pip install easyocr opencv-python pillow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 44.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.7/180.7 kB 10.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 978.2/978.2 kB 30.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.6/300.6 kB 19.6 MB/s eta 0:00:00
# ...

# %% [markdown]
# # EASY OCR

# %%
import easyocr
import cv2

reader = easyocr.Reader(['ru'], gpu=True)

img_path = "/content/test3.png"
img = cv2.imread(img_path)

results = reader.readtext(img)

for bbox, text, conf in results:
    print(f"{text}  | conf={conf:.2f}")

# %%
img_path = "/content/test5.jpg"
img = cv2.imread(img_path)

results = reader.readtext(img)

for bbox, text, conf in results:
    print(f"{text}  | conf={conf:.2f}")
# Out:
# 99  | conf=1.00
# 12  | conf=1.00
# 448292  | conf=0.76
# СОБСТВЕННИК  | conf=0.95
# владелец)  | conf=0.90
# СОЛДАТОВА  | conf=1.00
# SOLDATOVA  | conf=1.00
# НАДЕЖДА  | conf=1.00
# NADEZHDA  | conf=1.00
# ВАСИЛЬЕВНА  | conf=1.00
# Республика, край; обАасть  | conf=0.60
# Москва  | conf=1.00
# Район  | conf=1.00
# Нас.  | conf=0.54
# пункт  | conf=1.00
# Ухицаул Новорогожская  | conf=0.75
# Аом  | conf=0.84
# 28  | conf=1.00
# корт  | conf=0.55
# кв: 151  | conf=0.75
# Особые  | conf=0.68
# отметки  | conf=1.00
# 41.06.2019 ИЗМ. ВЛАДЕЛЬЦА ПО CB.O ПРНАСЛ Ng 77АГ 1  | conf=0.66
# 361471 OT 13.05.2019 НОТАРИУСОМ ЮРОВОЙ А А СДАН  | conf=0.51
# CTС 77ТА30З727  | conf=0.42
# поАразделения ГИБДА1145039  | conf=0.66
# 2019  | conf=1.00
# I  | conf=0.99
# 199 1 нЯ4 8292  | conf=0.36
# Код  | conf=0.99

# %%
img_path = "/content/test3.jpg"
img = cv2.imread(img_path)

results = reader.readtext(img)

for bbox, text, conf in results:
    print(f"{text}  | conf={conf:.2f}")
# Out:
# 99  | conf=1.00
# 82  | conf=1.00
# 334108  | conf=1.00
# СОБСТВЕННИК (вааделец)  | conf=0.44
# КОЕАЛАВА  | conf=1.00
# KOBALAVA  | conf=0.88
# МАКСИМ  | conf=0.98
# LL  | conf=0.29
# NAKSIM  | conf=0.93
# СуоОЖъЕссийской Федерации  | conf=0.10
# Москва  | conf=1.00
# F  | conf=0.13
# Населенный пункт  | conf=0.96
# Ухица  | conf=1.00
# ул Зоологическая  | conf=0.96
# Дом  | conf=0.57
# ["1"]  | conf=0.52
# Корпус (строение)  | conf=1.00
# Квартира 113  | conf=0.70
# 1"1 1  | conf=0.42
# 1"71  | conf=0.64
# Особые отметки  | conf=0.63
# ОФОРМЛЕНО С УЧЕТОМ РЕЕНИЙ СОВЕТАЕЭКОГ 95 D  | conf=0.62
# 42022 12 45 ИОТ 15 042022 N 77 ТЕРРИТОРИЯСЕРАЕНИЯ  | conf=0.34
# РФЛОСТАВЛЕНО НА УЧЕТ 27.11 2025 ЫСЩНССТЬ 243 кВ7  | conf=0.48
# 330 4 лс  | conf=0.75
# Код  | conf=0.91
# поАразделения ГИБАА  | conf=0.52
# 1145034  | conf=0.73
# 27.11.2025  | conf=0.92
# Аата выдачи  | conf=0.96
# 00О -ЗНАК = Москна 2025  | conf=0.24

# %% [markdown]
# # Вывод EASY OCR
# Путает буквы, очень часто заменяет русские английскими, качество плохое.

# %%
pip install python-doctr[torch]
# Out:
# ...
# WARNING: python-doctr 1.0.1 does not provide the extra 'torch'
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 33.2 MB/s  0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.5/17.5 MB 136.4 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 138.5 MB/s  0:00:00
# ...
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993335 sha256=ae75db59fab7b9e8534538cfa3500cad32b0d89043ecd97a0cbade40bdb61d19
#   Stored in directory: /root/.cache/pip/wheels/c1/67/88/e844b5b022812e15a52e4eaa38a1e709e99f06f6639d7e3ba7
# Successfully built langdetect
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6 [python-doctr]
# ...

# %%
import doctr
print(doctr.__version__)
# Out:
# v1.0.1

# %%
from doctr.io import DocumentFile
from doctr.models import ocr_predictor

model = ocr_predictor(pretrained=True)
# PDF
doc = DocumentFile.from_images("/content/test3.jpg")
# Analyze
result = model(doc)
# Out:
# ...
#   0%|          | 0/63303144 [00:00<?, ?it/s]

# %%
print(result.render())
# Out:
# 99
# 82
# 334108
# COBCTBEHHUK (BAaAeAen)
# KOSAJABA
# KOBALAVA
# MAKCMM
# MAKSIM
#
# JOPBEBWY
#
# CyobekT PoCCMicKON DeAepaynu
# :
# MocKBa
# T
# HaceneHublil TYHKT
# "T
# Vanua yn 3oonorwyeckan
# Aom
# 4
# CO
# Kopnyc (crpoenue)
# Keaprupa113
# 5
# C
# Ocooble OTMETKIL
# OPOPMNEHOC) YYETOM PELLIEHMM COBETAESKOT 050
# 42022Na45VOT 15.04.2022 No 77 TEPPMTOPMA 106PAUEHMA
# POTOCTABTEHORAYNET 27.11.2025 MOLLHOCTB243 KBT
# 3304 nc
# TMBAA 1145034
# KoA moapasaenemta
# 27.11.2025
# Aara BBlAauM
# 000 -3HAK-, Mocksa, 2025, Aw

# %%
doc = DocumentFile.from_images("/content/test4.jpg")
# Analyze
result = model(doc)

# %%
print(result.render())
# Out:
# 77
# Py
# 507054
# COBCTBEHHMK (BAaAeAeu)
# AAY3
# DAUE
# CBETIAHA
# SVETLANA
# ANEKCAHAHAPOBHA
# PecnyoAnka, kpan, O0AaCTb RF
# MOCKBA MOSKVA
# Panon
# 18,9OTA. MP30TVBAA LAO
# Hac. TYHKT
# Vanua RMOHEPCKAA6.
# Aom 37/38
# Kop.
# KB. 105
# Ocooble OTMETKW
# 05/12/2007707ROCTABNEHQHA Y4ET no AOK. AOrOBO
# PCOBEPULEDPOCTOWTTMCBMEHHOM OOPME KA-289/
# 201/28109/2007 OOQABTOUEHTP CKA T.MOCKBA
# 09 MBAAMOTTOP AMTC YTVBAA
# H.pocopn
# IOATnCE
# >
# 20
# T.
# 77 0512.20007054

# %%
doc = DocumentFile.from_images("/content/test5.jpg")
# Analyze
result = model(doc)
print(result.render())
# Out:
# 99 12 448292
# COBCTBEHHUK (BAaAeAen)
# CONAATOBA
# SOLDATOVA
# HAAEKIA
# NADEZHDA
# BACVIBEBHA
# Pecnyoanka, kpan, 00AaCTb
# MockBa
# Paion
# Hac. HYHKT
# Vanuayn HoBoporoxckag
# Aom 28
# KopI.
# KB. 151
# Ocoobie OTMETKI
# 11.06.2019V13M. BIAZEIBLATO CB.ONPHACING 77AF 1
# 361471 OT 13.05.2019 HOTAPMYCOM IOPOBOMAACIAH
# CTC 77TA303727
# A
# KOA moapasaeneuns T1BAA1145039
# 99
# 2019
# T.
# 199 12 40H48292

# %% [markdown]
# # Вывод doctr
# Не поддерживает кириллицу кажется

# %%
import easyocr
import pandas as pd
reader = easyocr.Reader(['ru'], gpu=True)

img = cv2.imread("/content/test3.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

results = reader.readtext(img)
df = pd.DataFrame(results, columns=['bbox', 'text', 'conf'])

# %%
df
# Out:
#                                                  bbox  \
# 0      [[52, 214], [126, 214], [126, 268], [52, 268]]
# 1    [[184, 214], [256, 214], [256, 268], [184, 268]]
# 2    [[313, 213], [517, 213], [517, 273], [313, 273]]
# 3      [[84, 285], [622, 285], [622, 337], [84, 337]]
# 4    [[143, 355], [404, 355], [404, 409], [143, 409]]
# 5    [[208, 392], [460, 392], [460, 442], [208, 442]]
# 6    [[149, 435], [358, 435], [358, 489], [149, 489]]
# 7    [[865, 441], [919, 441], [919, 477], [865, 477]]
# 8    [[209, 471], [400, 471], [400, 522], [209, 522]]
# 9      [[88, 504], [710, 504], [710, 605], [88, 605]]
# 10   [[169, 609], [305, 609], [305, 649], [169, 649]]
# 11     [[98, 648], [461, 648], [461, 693], [98, 693]]
# 12   [[102, 700], [223, 700], [223, 743], [102, 743]]
# 13   [[241, 701], [559, 701], [559, 745], [241, 745]]
# 14   [[860, 720], [886, 720], [886, 752], [860, 752]]
# 15   [[103, 751], [191, 751], [191, 795], [103, 795]]
# ...
